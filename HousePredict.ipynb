# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul7699/housepricepredict/blob/main/HousePredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("rahulhouse.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
feature_na=[feature for feature in df.columns if df[feature].isnull().sum()>1]
for feature in feature_na:
  print(feature, np.round(df[feature].isnull().mean(),4))
# Out:
# LotFrontage 0.1774
# Alley 0.9377
# MasVnrType 0.0055
# MasVnrArea 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageYrBlt 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
df[feature_na].head()
# Out:
#    LotFrontage Alley MasVnrType  MasVnrArea  ... GarageCond PoolQC Fence MiscFeature
# 0         65.0   NaN    BrkFace       196.0  ...         TA    NaN   NaN         NaN
# 1         80.0   NaN       None         0.0  ...         TA    NaN   NaN         NaN
# 2         68.0   NaN    BrkFace       162.0  ...         TA    NaN   NaN         NaN
# 3         60.0   NaN       None         0.0  ...         TA    NaN   NaN         NaN
# 4         84.0   NaN    BrkFace       350.0  ...         TA    NaN   NaN         NaN
#
# [5 rows x 18 columns]

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
